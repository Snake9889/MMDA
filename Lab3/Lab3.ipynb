# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn import tree
from sklearn import datasets
from sklearn import ensemble

# %% [markdown]
# Task 1

# %%
iris = datasets.load_iris()
iris_frame = pd.DataFrame(iris.data)
display(iris_frame)
X = iris.data
y = iris.target
clf = tree.DecisionTreeClassifier()
clf.fit(X, y)
fig, ax = plt.subplots(figsize=(12, 12))
tree.plot_tree(clf.fit(X, y), max_depth=4, fontsize=10)
plt.show()
# Out:
#        0    1    2    3
# 0    5.1  3.5  1.4  0.2
# 1    4.9  3.0  1.4  0.2
# 2    4.7  3.2  1.3  0.2
# 3    4.6  3.1  1.5  0.2
# 4    5.0  3.6  1.4  0.2
# ..   ...  ...  ...  ...
# 145  6.7  3.0  5.2  2.3
# 146  6.3  2.5  5.0  1.9
# 147  6.5  3.0  5.2  2.0
# 148  6.2  3.4  5.4  2.3
# 149  5.9  3.0  5.1  1.8
#
# [150 rows x 4 columns]

# %% [markdown]
# Task 2

# %%
clf = ensemble.GradientBoostingClassifier()
clf.fit(X, y)
print(clf.feature_importances_)
for estimators in clf.estimators_:
    for estimator in estimators:
        tree.plot_tree(estimator, class_names=True)
        plt.show()
# Out:
# [0.00653593 0.01171018 0.31973417 0.66201972]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-37-c304f18be72e> in <module>
#       5     for estimator in estimators:
#       6         tree.plot_tree(estimator, class_names=True)
# ----> 7         plt.show()
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in show(*args, **kw)
#     270     """
#     271     global _show
# --> 272     return _show(*args, **kw)
#     273
#     274
#
# ~\anaconda3\lib\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      39     try:
#      40         for figure_manager in Gcf.get_all_fig_managers():
# ---> 41             display(
#      42                 figure_manager.canvas.figure,
#      43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# ...

# %% [markdown]
# Task 3

# %%
Xmodel = np.concatenate((X[0:34], X[50:84], X[100:134]))
ymodel = np.concatenate((y[0:34], y[50:84], y[100:134]))
Xtest = np.concatenate((X[34:50], X[84:100], X[134:150]))
ytest = np.concatenate((y[34:50], y[84:100], y[134:150]))
test = []
mod = []
tick = []

for i in range(2, 20):
    clf = tree.DecisionTreeClassifier(max_leaf_nodes=i)
    clf.fit(Xmodel, ymodel)
    mod.append(clf.score(Xmodel,ymodel))
    test.append(clf.score(Xtest, ytest))
    tick.append(i)
    print('Decision Tree, model, capacity of leafs=' + str(i) + ': ' +
str(clf.score(Xmodel, ymodel)))
    print('Decision Tree, test, capacity of leafs=' + str(i) + ': ' +
str(clf.score(Xtest, ytest)))
 
plt.clf()
fig, axs = plt.subplots(2, 1, figsize=(10,7))
axs[0].plot(tick, test)
axs[0].set_title('test')
axs[1].plot(tick, mod)
axs[1].set_title('mod')
plt.show()
# Out:
# Decision Tree, model, capacity of leafs=2: 0.6666666666666666
# Decision Tree, test, capacity of leafs=2: 0.6666666666666666
# Decision Tree, model, capacity of leafs=3: 0.9509803921568627
# Decision Tree, test, capacity of leafs=3: 0.9791666666666666
# Decision Tree, model, capacity of leafs=4: 0.9607843137254902
# Decision Tree, test, capacity of leafs=4: 1.0
# Decision Tree, model, capacity of leafs=5: 0.9705882352941176
# Decision Tree, test, capacity of leafs=5: 1.0
# Decision Tree, model, capacity of leafs=6: 0.9803921568627451
# Decision Tree, test, capacity of leafs=6: 1.0
# Decision Tree, model, capacity of leafs=7: 0.9901960784313726
# Decision Tree, test, capacity of leafs=7: 1.0
# Decision Tree, model, capacity of leafs=8: 0.9901960784313726
# Decision Tree, test, capacity of leafs=8: 0.9791666666666666
# Decision Tree, model, capacity of leafs=9: 1.0
# Decision Tree, test, capacity of leafs=9: 1.0
# Decision Tree, model, capacity of leafs=10: 1.0
# ...

# %% [markdown]
# Task 4

# %%
test2 = []
mod2 = []
tick2 = []
plt.clf()
for i in range(2, 20):
    clf = ensemble.GradientBoostingClassifier(n_estimators=i)
    clf.fit(Xmodel, ymodel)
    mod2.append(clf.score(Xmodel,ymodel))
    test2.append(clf.score(Xtest, ytest))
    tick2.append(i)
    print('Gradient Boosting, model, capacity of trees=' + str(i) + ': ' +
str(clf.score(Xmodel, ymodel)))
    print('Gradient Boosting, test, capacity of trees=' + str(i) + ': ' +
str(clf.score(Xtest, ytest)))
    
fig, axs = plt.subplots(2, 1, figsize=(10,7))
axs[0].plot(tick2, test2)
axs[0].set_title('test')
axs[1].plot(tick2, mod2)
axs[1].set_title('mod')
plt.show()
# Out:
# Gradient Boosting, model, capacity of trees=2: 0.9901960784313726
# Gradient Boosting, test, capacity of trees=2: 1.0
# Gradient Boosting, model, capacity of trees=3: 0.9901960784313726
# Gradient Boosting, test, capacity of trees=3: 0.9791666666666666
# Gradient Boosting, model, capacity of trees=4: 0.9901960784313726
# Gradient Boosting, test, capacity of trees=4: 0.9791666666666666
# Gradient Boosting, model, capacity of trees=5: 1.0
# Gradient Boosting, test, capacity of trees=5: 1.0
# Gradient Boosting, model, capacity of trees=6: 1.0
# Gradient Boosting, test, capacity of trees=6: 0.9791666666666666
# Gradient Boosting, model, capacity of trees=7: 1.0
# Gradient Boosting, test, capacity of trees=7: 0.9791666666666666
# Gradient Boosting, model, capacity of trees=8: 1.0
# Gradient Boosting, test, capacity of trees=8: 1.0
# Gradient Boosting, model, capacity of trees=9: 1.0
# Gradient Boosting, test, capacity of trees=9: 0.9791666666666666
# ...

# %% [markdown]
# Task 5

# %%
test3 = []
mod3 = []
tick3 = []
plt.clf()
for i in range(2, 20):
    clf = ensemble.RandomForestClassifier(n_estimators=i)
    clf.fit(Xmodel, ymodel)
    mod3.append(clf.score(Xmodel,ymodel))
    test3.append(clf.score(Xtest, ytest))
    tick3.append(i)
    print('Random Forest, model, capacity of trees=' + str(i) + ': ' +
str(clf.score(Xmodel, ymodel)))
    print('Random Forest, test, capacity of trees=' + str(i) + ': ' +
str(clf.score(Xtest, ytest)))
fig, axs = plt.subplots(2, 1, figsize=(10,7))
axs[0].plot(tick3, test3)
axs[0].set_title('test')
axs[1].plot(tick3, mod3)
axs[1].set_title('mod')
plt.show()
# Out:
# Random Forest, model, capacity of trees=2: 0.9509803921568627
# Random Forest, test, capacity of trees=2: 0.9166666666666666
# Random Forest, model, capacity of trees=3: 0.9705882352941176
# Random Forest, test, capacity of trees=3: 0.9791666666666666
# Random Forest, model, capacity of trees=4: 1.0
# Random Forest, test, capacity of trees=4: 0.9583333333333334
# Random Forest, model, capacity of trees=5: 0.9901960784313726
# Random Forest, test, capacity of trees=5: 0.9791666666666666
# Random Forest, model, capacity of trees=6: 0.9901960784313726
# Random Forest, test, capacity of trees=6: 0.9791666666666666
# Random Forest, model, capacity of trees=7: 0.9803921568627451
# Random Forest, test, capacity of trees=7: 1.0
# Random Forest, model, capacity of trees=8: 1.0
# Random Forest, test, capacity of trees=8: 0.9583333333333334
# Random Forest, model, capacity of trees=9: 1.0
# Random Forest, test, capacity of trees=9: 1.0
# Random Forest, model, capacity of trees=10: 1.0
# ...
